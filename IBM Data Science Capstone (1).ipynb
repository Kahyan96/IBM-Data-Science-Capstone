# %% [markdown]
# <h1> IBM Data Science Capstone </h1>
# <p> This notebook will be mainly used for the capstone project </p>

# %%
import pandas as pd
import  numpy as np

# %%
print ("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 7.4 MB/s  eta 0:00:01
# Collecting branca
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=700ab321b91feca3f552a5d26f0719887d41f828274428c50599824448bcedab
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.5.0
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'W1MERJBEKLCR5DXSDELILM0VYAMJ2AFR42KHAWGQFCSXPQAT' # your Foursquare ID
CLIENT_SECRET = 'WME205ZHJ3HIP3JEQIYGAMB2AIQ5FMZS4NNNTLMXWYA0KSWH' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: W1MERJBEKLCR5DXSDELILM0VYAMJ2AFR42KHAWGQFCSXPQAT
# CLIENT_SECRET:WME205ZHJ3HIP3JEQIYGAMB2AIQ5FMZS4NNNTLMXWYA0KSWH

# %%
address = 'SS2, Malaysia'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 3.1172168 101.6155072

# %%
search_query = 'Restaurant, dessert'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Restaurant, dessert .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W1MERJBEKLCR5DXSDELILM0VYAMJ2AFR42KHAWGQFCSXPQAT&client_secret=WME205ZHJ3HIP3JEQIYGAMB2AIQ5FMZS4NNNTLMXWYA0KSWH&ll=3.1172168,101.6155072&v=20180604&query=Restaurant, dessert&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fbba74632abda5e0830f823'},
#  'response': {'venues': [{'id': '4b17c088f964a520c7c723e3',
#     'name': 'Restaurant Megah Good Luck 美佳鸿运海鲜餐室',
#     'location': {'address': 'Jalan SS24/2',
#      'crossStreet': 'Taman Megah',
#      'lat': 3.1144579612392076,
#      'lng': 101.61226572231087,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1144579612392076,
#        'lng': 101.61226572231087}],
#      'distance': 473,
#      'postalCode': '47301',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Jalan SS24/2 (Taman Megah)',
#       '47301 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '5c8f6b1d28374e002cd5bebb',
#     'name': 'Restaurant Mama Ting',
#     'location': {'address': '8 Jalan SS2/10',
#      'lat': 3.115211,
#      'lng': 101.616525,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.115211,
#        'lng': 101.616525}],
#      'distance': 250,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['8 Jalan SS2/10',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'shortName': 'Noodles',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4e8ad55f49018e0360ddd9bc',
#     'name': 'Restaurant Lim Mee Yoke',
#     'location': {'address': '14, Jalan SS2/10',
#      'lat': 3.115361428531432,
#      'lng': 101.61666726129218,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.115361428531432,
#        'lng': 101.61666726129218}],
#      'distance': 243,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['14, Jalan SS2/10',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4c2f32fa213c2d7fd864305d',
#     'name': 'Restaurant Nyuk Min 玉明美食小廚',
#     'location': {'address': 'SS2',
#      'lat': 3.119451565558448,
#      'lng': 101.62032646811791,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.119451565558448,
#        'lng': 101.62032646811791}],
#      'distance': 590,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'neighborhood': 'SS2',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['SS2', '47300 Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4b83f83df964a520f31831e3',
#     'name': 'Restaurant Teow Chew Meng',
#     'location': {'address': '33, Jalan SS 2/30',
#      'lat': 3.1136531810751507,
#      'lng': 101.62126772216232,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1136531810751507,
#        'lng': 101.62126772216232}],
#      'distance': 753,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['33, Jalan SS 2/30',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4bf290869319a5932711cb51',
#     'name': 'Chow Yang Restaurant',
#     'location': {'address': 'Bandar Utama',
#      'lat': 3.116391031732587,
#      'lng': 101.61679758194218,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.116391031732587,
#        'lng': 101.61679758194218}],
#      'distance': 170,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'neighborhood': 'Taman SEA',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Bandar Utama',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '553b716e498efecdca34d347',
#     'name': 'Restaurant Lucky Home Mix Rice 家好运',
#     'location': {'address': 'Jalan 21/19',
#      'lat': 3.109004872088202,
#      'lng': 101.62225675369947,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.109004872088202,
#        'lng': 101.62225675369947}],
#      'distance': 1182,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Jalan 21/19',
#       'Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4b8b46fdf964a520919a32e3',
#     'name': 'Restaurant Sun Yin Loong (新源隆茶室)',
#     'location': {'address': 'Aman Suria',
#      'crossStreet': 'Sunwaymas Commercial Centre',
#      'lat': 3.120048914455734,
#      'lng': 101.59848392208252,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.120048914455734,
#        'lng': 101.59848392208252}],
#      'distance': 1918,
#      'postalCode': '47301',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Aman Suria (Sunwaymas Commercial Centre)',
#       '47301 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4b6c1f39f964a520e7242ce3',
#     'name': 'Restaurant Wong Poh 旺来海鲜饭店',
#     'location': {'address': '2-42 Jalan BM 1/2',
#      'lat': 3.1243769178482403,
#      'lng': 101.59540937502766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1243769178482403,
#        'lng': 101.59540937502766}],
#      'distance': 2371,
#      'postalCode': '47301',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['2-42 Jalan BM 1/2',
#       '47301 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '5822d3ff4c6d6738729f51a8',
#     'name': 'The Dessert Workshop 甜品工房',
#     'location': {'lat': 3.1199847642286356,
#      'lng': 101.62151368262693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1199847642286356,
#        'lng': 101.62151368262693}],
#      'distance': 735,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4c22e8c099282d7f93f367b0',
#     'name': 'Soong Foong Inn Vegetarian Restaurant',
#     'location': {'address': '22, Jalan SS 23/11, Taman SEA',
#      'lat': 3.1182133992952914,
#      'lng': 101.61368226818298,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1182133992952914,
#        'lng': 101.61368226818298}],
#      'distance': 231,
#      'postalCode': '47400',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['22, Jalan SS 23/11, Taman SEA',
#       '47400 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4c0b882fffb8c9b6ec5e6d61',
#     'name': 'Hol Thong Restaurant',
#     'location': {'lat': 3.1178285553407346,
#      'lng': 101.61382273773667,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1178285553407346,
#        'lng': 101.61382273773667}],
#      'distance': 199,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '57a87bc9498e6ebdc03c666a',
#     'name': 'Restaurant Yau Hau Fook 有口福小食馆',
#     'location': {'address': 'NO.25, Jalan SS2/30',
#      'lat': 3.11345,
#      'lng': 101.621164,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.11345,
#        'lng': 101.621164}],
#      'distance': 755,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'city': 'SS2',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['NO.25, Jalan SS2/30',
#       '47300 SS2, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4c00efe19a950f47995108c6',
#     'name': 'Restaurant How Ye Kee 好义记小炒',
#     'location': {'address': '614-620 Jalan 17/10',
#      'crossStreet': 'SS17',
#      'lat': 3.122048,
#      'lng': 101.635806,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.122048,
#        'lng': 101.635806}],
#      'distance': 2319,
#      'postalCode': '46400',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['614-620 Jalan 17/10 (SS17)',
#       '46400 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4bb3ee3887aa952166b1acd1',
#     'name': 'Restaurant AS',
#     'location': {'address': 'Aman Suria',
#      'lat': 3.1208578603085866,
#      'lng': 101.59705795186855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1208578603085866,
#        'lng': 101.59705795186855}],
#      'distance': 2090,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Aman Suria',
#       'Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '50717073e4b0513ffd93afac',
#     'name': 'Restaurant Sun Yau Tak Teng 新有得顶海鲜菜馆',
#     'location': {'address': 'No. 1, Jalan SS20/11',
#      'crossStreet': 'Damansara Utama / Kim',
#      'lat': 3.1346248972206703,
#      'lng': 101.62571895551024,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1346248972206703,
#        'lng': 101.62571895551024}],
#      'distance': 2245,
#      'postalCode': '47400',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['No. 1, Jalan SS20/11 (Damansara Utama / Kim)',
#       '47400 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4c90cc3a51d9b1f701de7a46',
#     'name': 'Restaurant Happy (Siong Hee) @ SS3',
#     'location': {'address': 'Jalan SS3/37',
#      'crossStreet': 'Jalan SS3/66',
#      'lat': 3.0976069601054506,
#      'lng': 101.61325716204335,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.0976069601054506,
#        'lng': 101.61325716204335}],
#      'distance': 2197,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Jalan SS3/37 (Jalan SS3/66)',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '51b79a755019e55e92d9424f',
#     'name': 'Restaurant Hong Hui 红喜茶餐室',
#     'location': {'address': '1, Jalan SS 22/11',
#      'crossStreet': 'Damansara Jaya',
#      'lat': 3.1319591817263075,
#      'lng': 101.62097963500294,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1319591817263075,
#        'lng': 101.62097963500294}],
#      'distance': 1750,
#      'postalCode': '47400',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['1, Jalan SS 22/11 (Damansara Jaya)',
#       '47400 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4b38d416f964a520da5025e3',
#     'name': 'K.T.Z. Food (记得食)',
#     'location': {'address': '66 & 68, Jalan SS2/67',
#      'lat': 3.1184280930725063,
#      'lng': 101.62229159609423,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1184280930725063,
#        'lng': 101.62229159609423}],
#      'distance': 766,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'neighborhood': 'SS2',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['66 & 68, Jalan SS2/67',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '5263d0ab11d25d346732c46f',
#     'name': 'Yu Yi Seafood Restaurant 友谊海鲜饭店',
#     'location': {'lat': 3.1156539575769084,
#      'lng': 101.62191520844316,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1156539575769084,
#        'lng': 101.62191520844316}],
#      'distance': 733,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4b0f6465f964a520fb6123e3',
#     'name': 'Jin Xuan Hong Kong Restaurant (锦选香港特极点心)',
#     'location': {'address': '59, 61 & 63 Jalan SS 22/19',
#      'crossStreet': 'Damansara Jaya',
#      'lat': 3.126745892048449,
#      'lng': 101.61531402086445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.126745892048449,
#        'lng': 101.61531402086445}],
#      'distance': 1060,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['59, 61 & 63 Jalan SS 22/19 (Damansara Jaya)',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '5a5c74e6e57ca6276a437c12',
#     'name': 'Restaurant Lucky Home Mix Rice',
#     'location': {'address': '18 Jalan 21/19',
#      'lat': 3.108933,
#      'lng': 101.622551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.108933,
#        'lng': 101.622551}],
#      'distance': 1209,
#      'postalCode': '46300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['18 Jalan 21/19',
#       '46300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '522310f511d20413228a1fdd',
#     'name': 'Restaurant Alfa Maju',
#     'location': {'address': 'Parklane, Kelana Jaya',
#      'lat': 3.1091110546954264,
#      'lng': 101.59329199657489,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1091110546954264,
#        'lng': 101.59329199657489}],
#      'distance': 2629,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Parklane, Kelana Jaya',
#       'Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d156941735',
#       'name': 'Malay Restaurant',
#       'pluralName': 'Malay Restaurants',
#       'shortName': 'Malay',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4b933580f964a520463b34e3',
#     'name': 'Restaurant Kean Fatt',
#     'location': {'address': 'Taman Bahagia',
#      'lat': 3.1095214465388317,
#      'lng': 101.61160827474279,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1095214465388317,
#        'lng': 101.61160827474279}],
#      'distance': 960,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Taman Bahagia',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4db4133dfa8c350240dca7e1',
#     'name': 'Lucky Loke Restaurant',
#     'location': {'address': '2 Jalan SS 3/59E',
#      'lat': 3.1094482482583183,
#      'lng': 101.61166638069302,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1094482482583183,
#        'lng': 101.61166638069302}],
#      'distance': 964,
#      'postalCode': '47301',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['2 Jalan SS 3/59E',
#       '47301 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4d400a091bd2a143eaa3ee7c',
#     'name': 'Hong Kong Dessert 甜品哥哥',
#     'location': {'address': 'Ss2/63',
#      'lat': 3.118811901601927,
#      'lng': 101.62194728851318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.118811901601927,
#        'lng': 101.62194728851318}],
#      'distance': 737,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Ss2/63', 'Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4f0668aa6da1d1ed2c9e042e',
#     'name': 'Daorae Korean BBQ Restaurant',
#     'location': {'address': 'Jalan SS 2/67',
#      'lat': 3.1201178155798144,
#      'lng': 101.62137318339681,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1201178155798144,
#        'lng': 101.62137318339681}],
#      'distance': 727,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Jalan SS 2/67',
#       'Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4bd7becbe914a59334fb51fa',
#     'name': 'LaLa Chong Seafood Restaurant',
#     'location': {'address': '13556, Jalan Cempaka, Kayu Ara Damansara',
#      'lat': 3.1242285801400937,
#      'lng': 101.60800189547695,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1242285801400937,
#        'lng': 101.60800189547695}],
#      'distance': 1142,
#      'postalCode': '47400',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['13556, Jalan Cempaka, Kayu Ara Damansara',
#       '47400 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4d84a0bcf9f3a1cd662ab964',
#     'name': 'Restaurant Thong Kee, Sea Park PJ',
#     'location': {'address': '33,Jalan 21/1,Sea Park',
#      'lat': 3.108383770177461,
#      'lng': 101.62271622569618,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.108383770177461,
#        'lng': 101.62271622569618}],
#      'distance': 1268,
#      'postalCode': '46300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['33,Jalan 21/1,Sea Park',
#       '46300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False},
#    {'id': '4c160d927f7f2d7fe649e368',
#     'name': 'Chef Chan Seafood Restaurant (金华海鲜饭店)',
#     'location': {'address': 'No. 40 , SS2/10',
#      'lat': 3.1160563552384573,
#      'lng': 101.6171914212723,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1160563552384573,
#        'lng': 101.6171914212723}],
#      'distance': 227,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['No. 40 , SS2/10',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606133574',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                                 name  \
# 0  4b17c088f964a520c7c723e3  Restaurant Megah Good Luck 美佳鸿运海鲜餐室
# 1  5c8f6b1d28374e002cd5bebb                 Restaurant Mama Ting
# 2  4e8ad55f49018e0360ddd9bc              Restaurant Lim Mee Yoke
# 3  4c2f32fa213c2d7fd864305d           Restaurant Nyuk Min 玉明美食小廚
# 4  4b83f83df964a520f31831e3            Restaurant Teow Chew Meng
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1606133574    False
# 1  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...  v-1606133574    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1606133574    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1606133574    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1606133574    False
#
#     location.address location.crossStreet  location.lat  location.lng  \
# 0       Jalan SS24/2          Taman Megah      3.114458    101.612266
# 1     8 Jalan SS2/10                  NaN      3.115211    101.616525
# 2   14, Jalan SS2/10                  NaN      3.115361    101.616667
# 3                SS2                  NaN      3.119452    101.620326
# 4  33, Jalan SS 2/30                  NaN      3.113653    101.621268
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 3.114457961239207...                473
# 1  [{'label': 'display', 'lat': 3.115211, 'lng': ...                250
# 2  [{'label': 'display', 'lat': 3.115361428531432...                243
# 3  [{'label': 'display', 'lat': 3.119451565558448...                590
# 4  [{'label': 'display', 'lat': 3.113653181075150...                753
#
#   location.postalCode location.cc  location.city location.state  \
# 0               47301          MY  Petaling Jaya       Selangor
# 1               47300          MY  Petaling Jaya       Selangor
# 2               47300          MY  Petaling Jaya       Selangor
# 3               47300          MY  Petaling Jaya       Selangor
# 4               47300          MY  Petaling Jaya       Selangor
#
#   location.country                          location.formattedAddress  \
# 0         Malaysia  [Jalan SS24/2 (Taman Megah), 47301 Petaling Ja...
# 1         Malaysia  [8 Jalan SS2/10, 47300 Petaling Jaya, Selangor...
# 2         Malaysia  [14, Jalan SS2/10, 47300 Petaling Jaya, Selang...
# 3         Malaysia     [SS2, 47300 Petaling Jaya, Selangor, Malaysia]
# 4         Malaysia  [33, Jalan SS 2/30, 47300 Petaling Jaya, Selan...
#
#   location.neighborhood
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   SS2
# 4                   NaN

# %%
dataframe.shape [0]
# Out:
# 30

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                         name                     categories  \
# 0        Restaurant Megah Good Luck 美佳鸿运海鲜餐室             Chinese Restaurant
# 1                       Restaurant Mama Ting                   Noodle House
# 2                    Restaurant Lim Mee Yoke             Chinese Restaurant
# 3                 Restaurant Nyuk Min 玉明美食小廚             Chinese Restaurant
# 4                  Restaurant Teow Chew Meng             Chinese Restaurant
# 5                       Chow Yang Restaurant             Chinese Restaurant
# 6         Restaurant Lucky Home Mix Rice 家好运             Chinese Restaurant
# 7           Restaurant Sun Yin Loong (新源隆茶室)             Chinese Restaurant
# 8                 Restaurant Wong Poh 旺来海鲜饭店             Chinese Restaurant
# 9                  The Dessert Workshop 甜品工房                           Café
# 10     Soong Foong Inn Vegetarian Restaurant  Vegetarian / Vegan Restaurant
# 11                      Hol Thong Restaurant             Chinese Restaurant
# 12            Restaurant Yau Hau Fook 有口福小食馆               Asian Restaurant
# 13               Restaurant How Ye Kee 好义记小炒             Chinese Restaurant
# 14                             Restaurant AS                    Coffee Shop
# 15      Restaurant Sun Yau Tak Teng 新有得顶海鲜菜馆               Asian Restaurant
# 16        Restaurant Happy (Siong Hee) @ SS3               Asian Restaurant
# 17                 Restaurant Hong Hui 红喜茶餐室             Chinese Restaurant
# 18                         K.T.Z. Food (记得食)                   Dessert Shop
# 19           Yu Yi Seafood Restaurant 友谊海鲜饭店               Asian Restaurant
# 20  Jin Xuan Hong Kong Restaurant (锦选香港特极点心)             Dim Sum Restaurant
# 21            Restaurant Lucky Home Mix Rice                      Cafeteria
# 22                      Restaurant Alfa Maju               Malay Restaurant
# 23                      Restaurant Kean Fatt             Chinese Restaurant
# 24                     Lucky Loke Restaurant             Chinese Restaurant
# 25                    Hong Kong Dessert 甜品哥哥                   Dessert Shop
# 26              Daorae Korean BBQ Restaurant              Korean Restaurant
# 27             LaLa Chong Seafood Restaurant             Seafood Restaurant
# 28         Restaurant Thong Kee, Sea Park PJ             Chinese Restaurant
# 29     Chef Chan Seafood Restaurant (金华海鲜饭店)               Asian Restaurant
#
#                                      address                  crossStreet  \
# 0                               Jalan SS24/2                  Taman Megah
# 1                             8 Jalan SS2/10                          NaN
# 2                           14, Jalan SS2/10                          NaN
# 3                                        SS2                          NaN
# 4                          33, Jalan SS 2/30                          NaN
# 5                               Bandar Utama                          NaN
# 6                                Jalan 21/19                          NaN
# 7                                 Aman Suria  Sunwaymas Commercial Centre
# 8                          2-42 Jalan BM 1/2                          NaN
# 9                                        NaN                          NaN
# 10             22, Jalan SS 23/11, Taman SEA                          NaN
# 11                                       NaN                          NaN
# 12                       NO.25, Jalan SS2/30                          NaN
# 13                       614-620 Jalan 17/10                         SS17
# 14                                Aman Suria                          NaN
# 15                      No. 1, Jalan SS20/11        Damansara Utama / Kim
# 16                              Jalan SS3/37                 Jalan SS3/66
# 17                         1, Jalan SS 22/11               Damansara Jaya
# 18                     66 & 68, Jalan SS2/67                          NaN
# 19                                       NaN                          NaN
# 20                59, 61 & 63 Jalan SS 22/19               Damansara Jaya
# 21                            18 Jalan 21/19                          NaN
# 22                     Parklane, Kelana Jaya                          NaN
# 23                             Taman Bahagia                          NaN
# 24                          2 Jalan SS 3/59E                          NaN
# 25                                    Ss2/63                          NaN
# 26                             Jalan SS 2/67                          NaN
# 27  13556, Jalan Cempaka, Kayu Ara Damansara                          NaN
# 28                    33,Jalan 21/1,Sea Park                          NaN
# 29                           No. 40 , SS2/10                          NaN
#
#          lat         lng                                     labeledLatLngs  \
# 0   3.114458  101.612266  [{'label': 'display', 'lat': 3.114457961239207...
# 1   3.115211  101.616525  [{'label': 'display', 'lat': 3.115211, 'lng': ...
# 2   3.115361  101.616667  [{'label': 'display', 'lat': 3.115361428531432...
# 3   3.119452  101.620326  [{'label': 'display', 'lat': 3.119451565558448...
# 4   3.113653  101.621268  [{'label': 'display', 'lat': 3.113653181075150...
# 5   3.116391  101.616798  [{'label': 'display', 'lat': 3.116391031732587...
# 6   3.109005  101.622257  [{'label': 'display', 'lat': 3.109004872088202...
# 7   3.120049  101.598484  [{'label': 'display', 'lat': 3.120048914455734...
# 8   3.124377  101.595409  [{'label': 'display', 'lat': 3.124376917848240...
# 9   3.119985  101.621514  [{'label': 'display', 'lat': 3.119984764228635...
# 10  3.118213  101.613682  [{'label': 'display', 'lat': 3.118213399295291...
# 11  3.117829  101.613823  [{'label': 'display', 'lat': 3.117828555340734...
# 12  3.113450  101.621164  [{'label': 'display', 'lat': 3.11345, 'lng': 1...
# 13  3.122048  101.635806  [{'label': 'display', 'lat': 3.122048, 'lng': ...
# 14  3.120858  101.597058  [{'label': 'display', 'lat': 3.120857860308586...
# 15  3.134625  101.625719  [{'label': 'display', 'lat': 3.134624897220670...
# 16  3.097607  101.613257  [{'label': 'display', 'lat': 3.097606960105450...
# 17  3.131959  101.620980  [{'label': 'display', 'lat': 3.131959181726307...
# 18  3.118428  101.622292  [{'label': 'display', 'lat': 3.118428093072506...
# 19  3.115654  101.621915  [{'label': 'display', 'lat': 3.115653957576908...
# 20  3.126746  101.615314  [{'label': 'display', 'lat': 3.126745892048449...
# 21  3.108933  101.622551  [{'label': 'display', 'lat': 3.108933, 'lng': ...
# 22  3.109111  101.593292  [{'label': 'display', 'lat': 3.109111054695426...
# 23  3.109521  101.611608  [{'label': 'display', 'lat': 3.109521446538831...
# 24  3.109448  101.611666  [{'label': 'display', 'lat': 3.109448248258318...
# 25  3.118812  101.621947  [{'label': 'display', 'lat': 3.118811901601927...
# 26  3.120118  101.621373  [{'label': 'display', 'lat': 3.120117815579814...
# 27  3.124229  101.608002  [{'label': 'display', 'lat': 3.124228580140093...
# 28  3.108384  101.622716  [{'label': 'display', 'lat': 3.108383770177461...
# 29  3.116056  101.617191  [{'label': 'display', 'lat': 3.116056355238457...
#
#     distance postalCode  cc           city     state   country  \
# 0        473      47301  MY  Petaling Jaya  Selangor  Malaysia
# 1        250      47300  MY  Petaling Jaya  Selangor  Malaysia
# 2        243      47300  MY  Petaling Jaya  Selangor  Malaysia
# 3        590      47300  MY  Petaling Jaya  Selangor  Malaysia
# 4        753      47300  MY  Petaling Jaya  Selangor  Malaysia
# 5        170      47300  MY  Petaling Jaya  Selangor  Malaysia
# 6       1182        NaN  MY  Petaling Jaya  Selangor  Malaysia
# 7       1918      47301  MY  Petaling Jaya  Selangor  Malaysia
# 8       2371      47301  MY  Petaling Jaya  Selangor  Malaysia
# 9        735        NaN  MY  Petaling Jaya  Selangor  Malaysia
# 10       231      47400  MY  Petaling Jaya  Selangor  Malaysia
# 11       199        NaN  MY  Petaling Jaya  Selangor  Malaysia
# 12       755      47300  MY            SS2  Selangor  Malaysia
# 13      2319      46400  MY  Petaling Jaya  Selangor  Malaysia
# 14      2090        NaN  MY  Petaling Jaya  Selangor  Malaysia
# 15      2245      47400  MY  Petaling Jaya  Selangor  Malaysia
# 16      2197      47300  MY  Petaling Jaya  Selangor  Malaysia
# 17      1750      47400  MY  Petaling Jaya  Selangor  Malaysia
# 18       766      47300  MY  Petaling Jaya  Selangor  Malaysia
# 19       733        NaN  MY  Petaling Jaya  Selangor  Malaysia
# 20      1060      47300  MY  Petaling Jaya  Selangor  Malaysia
# 21      1209      46300  MY  Petaling Jaya  Selangor  Malaysia
# 22      2629        NaN  MY  Petaling Jaya  Selangor  Malaysia
# 23       960      47300  MY  Petaling Jaya  Selangor  Malaysia
# 24       964      47301  MY  Petaling Jaya  Selangor  Malaysia
# 25       737        NaN  MY  Petaling Jaya  Selangor  Malaysia
# 26       727        NaN  MY  Petaling Jaya  Selangor  Malaysia
# 27      1142      47400  MY  Petaling Jaya  Selangor  Malaysia
# 28      1268      46300  MY  Petaling Jaya  Selangor  Malaysia
# 29       227      47300  MY  Petaling Jaya  Selangor  Malaysia
#
#                                      formattedAddress neighborhood  \
# 0   [Jalan SS24/2 (Taman Megah), 47301 Petaling Ja...          NaN
# 1   [8 Jalan SS2/10, 47300 Petaling Jaya, Selangor...          NaN
# 2   [14, Jalan SS2/10, 47300 Petaling Jaya, Selang...          NaN
# 3      [SS2, 47300 Petaling Jaya, Selangor, Malaysia]          SS2
# 4   [33, Jalan SS 2/30, 47300 Petaling Jaya, Selan...          NaN
# 5   [Bandar Utama, 47300 Petaling Jaya, Selangor, ...    Taman SEA
# 6    [Jalan 21/19, Petaling Jaya, Selangor, Malaysia]          NaN
# 7   [Aman Suria (Sunwaymas Commercial Centre), 473...          NaN
# 8   [2-42 Jalan BM 1/2, 47301 Petaling Jaya, Selan...          NaN
# 9                 [Petaling Jaya, Selangor, Malaysia]          NaN
# 10  [22, Jalan SS 23/11, Taman SEA, 47400 Petaling...          NaN
# 11                [Petaling Jaya, Selangor, Malaysia]          NaN
# 12  [NO.25, Jalan SS2/30, 47300 SS2, Selangor, Mal...          NaN
# 13  [614-620 Jalan 17/10 (SS17), 46400 Petaling Ja...          NaN
# 14    [Aman Suria, Petaling Jaya, Selangor, Malaysia]          NaN
# 15  [No. 1, Jalan SS20/11 (Damansara Utama / Kim),...          NaN
# 16  [Jalan SS3/37 (Jalan SS3/66), 47300 Petaling J...          NaN
# 17  [1, Jalan SS 22/11 (Damansara Jaya), 47400 Pet...          NaN
# 18  [66 & 68, Jalan SS2/67, 47300 Petaling Jaya, S...          SS2
# 19                [Petaling Jaya, Selangor, Malaysia]          NaN
# 20  [59, 61 & 63 Jalan SS 22/19 (Damansara Jaya), ...          NaN
# 21  [18 Jalan 21/19, 46300 Petaling Jaya, Selangor...          NaN
# 22  [Parklane, Kelana Jaya, Petaling Jaya, Selango...          NaN
# 23  [Taman Bahagia, 47300 Petaling Jaya, Selangor,...          NaN
# 24  [2 Jalan SS 3/59E, 47301 Petaling Jaya, Selang...          NaN
# 25        [Ss2/63, Petaling Jaya, Selangor, Malaysia]          NaN
# 26  [Jalan SS 2/67, Petaling Jaya, Selangor, Malay...          NaN
# 27  [13556, Jalan Cempaka, Kayu Ara Damansara, 474...          NaN
# 28  [33,Jalan 21/1,Sea Park, 46300 Petaling Jaya, ...          NaN
# 29  [No. 40 , SS2/10, 47300 Petaling Jaya, Selango...          NaN
#
#                           id
# 0   4b17c088f964a520c7c723e3
# 1   5c8f6b1d28374e002cd5bebb
# 2   4e8ad55f49018e0360ddd9bc
# 3   4c2f32fa213c2d7fd864305d
# 4   4b83f83df964a520f31831e3
# 5   4bf290869319a5932711cb51
# 6   553b716e498efecdca34d347
# 7   4b8b46fdf964a520919a32e3
# 8   4b6c1f39f964a520e7242ce3
# 9   5822d3ff4c6d6738729f51a8
# 10  4c22e8c099282d7f93f367b0
# 11  4c0b882fffb8c9b6ec5e6d61
# 12  57a87bc9498e6ebdc03c666a
# 13  4c00efe19a950f47995108c6
# 14  4bb3ee3887aa952166b1acd1
# 15  50717073e4b0513ffd93afac
# 16  4c90cc3a51d9b1f701de7a46
# 17  51b79a755019e55e92d9424f
# 18  4b38d416f964a520da5025e3
# 19  5263d0ab11d25d346732c46f
# 20  4b0f6465f964a520fb6123e3
# 21  5a5c74e6e57ca6276a437c12
# 22  522310f511d20413228a1fdd
# 23  4b933580f964a520463b34e3
# 24  4db4133dfa8c350240dca7e1
# 25  4d400a091bd2a143eaa3ee7c
# 26  4f0668aa6da1d1ed2c9e042e
# 27  4bd7becbe914a59334fb51fa
# 28  4d84a0bcf9f3a1cd662ab964
# 29  4c160d927f7f2d7fe649e368

# %%
dataframe_filtered.name
# Out:
# 0          Restaurant Megah Good Luck 美佳鸿运海鲜餐室
# 1                         Restaurant Mama Ting
# 2                      Restaurant Lim Mee Yoke
# 3                   Restaurant Nyuk Min 玉明美食小廚
# 4                    Restaurant Teow Chew Meng
# 5                         Chow Yang Restaurant
# 6           Restaurant Lucky Home Mix Rice 家好运
# 7             Restaurant Sun Yin Loong (新源隆茶室)
# 8                   Restaurant Wong Poh 旺来海鲜饭店
# 9                    The Dessert Workshop 甜品工房
# 10       Soong Foong Inn Vegetarian Restaurant
# 11                        Hol Thong Restaurant
# 12              Restaurant Yau Hau Fook 有口福小食馆
# 13                 Restaurant How Ye Kee 好义记小炒
# 14                               Restaurant AS
# 15        Restaurant Sun Yau Tak Teng 新有得顶海鲜菜馆
# 16          Restaurant Happy (Siong Hee) @ SS3
# 17                   Restaurant Hong Hui 红喜茶餐室
# 18                           K.T.Z. Food (记得食)
# 19             Yu Yi Seafood Restaurant 友谊海鲜饭店
# 20    Jin Xuan Hong Kong Restaurant (锦选香港特极点心)
# 21              Restaurant Lucky Home Mix Rice
# 22                        Restaurant Alfa Maju
# 23                        Restaurant Kean Fatt
# 24                       Lucky Loke Restaurant
# 25                      Hong Kong Dessert 甜品哥哥
# 26                Daorae Korean BBQ Restaurant
# 27               LaLa Chong Seafood Restaurant
# 28           Restaurant Thong Kee, Sea Park PJ
# 29       Chef Chan Seafood Restaurant (金华海鲜饭店)
# Name: name, dtype: object

# %%
name = dataframe_filtered.name

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the Conrad Hotel

folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='SS2',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, name in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        color='blue',
        popup= name,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query = 'Dessert'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Dessert .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=W1MERJBEKLCR5DXSDELILM0VYAMJ2AFR42KHAWGQFCSXPQAT&client_secret=WME205ZHJ3HIP3JEQIYGAMB2AIQ5FMZS4NNNTLMXWYA0KSWH&ll=3.1172168,101.6155072&v=20180604&query=Dessert&radius=1000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fbb7061dfad1e14dfaefaae'},
#  'response': {'venues': [{'id': '5822d3ff4c6d6738729f51a8',
#     'name': 'The Dessert Workshop 甜品工房',
#     'location': {'lat': 3.1199847642286356,
#      'lng': 101.62151368262693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1199847642286356,
#        'lng': 101.62151368262693}],
#      'distance': 735,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '4d400a091bd2a143eaa3ee7c',
#     'name': 'Hong Kong Dessert 甜品哥哥',
#     'location': {'address': 'Ss2/63',
#      'lat': 3.118811901601927,
#      'lng': 101.62194728851318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.118811901601927,
#        'lng': 101.62194728851318}],
#      'distance': 737,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['Ss2/63', 'Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '4f926ff0e4b0dcd91191bdce',
#     'name': 'Sisters Dessert',
#     'location': {'lat': 3.1143577098846436,
#      'lng': 101.61228942871094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1143577098846436,
#        'lng': 101.61228942871094}],
#      'distance': 478,
#      'cc': 'MY',
#      'country': 'Malaysia',
#      'formattedAddress': ['Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '4ffd7cafe4b0cb44d977af12',
#     'name': 'Ice Palace Dessert',
#     'location': {'lat': 3.11422694810422,
#      'lng': 101.61156397514624,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.11422694810422,
#        'lng': 101.61156397514624}],
#      'distance': 550,
#      'cc': 'MY',
#      'country': 'Malaysia',
#      'formattedAddress': ['Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '5a6043fc6adbf51970020930',
#     'name': 'Tim’s Dessert',
#     'location': {'lat': 3.113464,
#      'lng': 101.611,
#      'labeledLatLngs': [{'label': 'display', 'lat': 3.113464, 'lng': 101.611}],
#      'distance': 652,
#      'postalCode': '47301',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['47301 Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '4dce89e5e4cd130e1668caab',
#     'name': 'Hong Kong Dessert',
#     'location': {'address': 'SS2',
#      'lat': 3.115518555061557,
#      'lng': 101.62129832944082,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.115518555061557,
#        'lng': 101.62129832944082}],
#      'distance': 670,
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['SS2', 'Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '4f6f41c7e4b0738fb3dedccf',
#     'name': 'D&J Dessert Stall',
#     'location': {'address': 'Restoran Sun Hin Loong',
#      'crossStreet': 'SS2, Petaling Jaya',
#      'lat': 3.1200287798961686,
#      'lng': 101.62150738180287,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1200287798961686,
#        'lng': 101.62150738180287}],
#      'distance': 736,
#      'cc': 'MY',
#      'country': 'Malaysia',
#      'formattedAddress': ['Restoran Sun Hin Loong (SS2, Petaling Jaya)',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '4fe56f53e4b032d6530f4836',
#     'name': 'One Dessert',
#     'location': {'crossStreet': 'SS2',
#      'lat': 3.1170344088317394,
#      'lng': 101.62210179459035,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1170344088317394,
#        'lng': 101.62210179459035}],
#      'distance': 733,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['SS2', '47300 Petaling Jaya, Selangor', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '544116c1498e51b65b4d3f5f',
#     'name': 'U Dessert',
#     'location': {'lat': 3.118791068891402,
#      'lng': 101.62319063437577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.118791068891402,
#        'lng': 101.62319063437577}],
#      'distance': 871,
#      'cc': 'MY',
#      'country': 'Malaysia',
#      'formattedAddress': ['Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '4b38d416f964a520da5025e3',
#     'name': 'K.T.Z. Food (记得食)',
#     'location': {'address': '66 & 68, Jalan SS2/67',
#      'lat': 3.1184280930725063,
#      'lng': 101.62229159609423,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1184280930725063,
#        'lng': 101.62229159609423}],
#      'distance': 766,
#      'postalCode': '47300',
#      'cc': 'MY',
#      'neighborhood': 'SS2',
#      'city': 'Petaling Jaya',
#      'state': 'Selangor',
#      'country': 'Malaysia',
#      'formattedAddress': ['66 & 68, Jalan SS2/67',
#       '47300 Petaling Jaya, Selangor',
#       'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False},
#    {'id': '50068edae4b09db42e113b27',
#     'name': '一品糖one desserts',
#     'location': {'address': 'Ss2',
#      'crossStreet': 'Petaling Jaya',
#      'lat': 3.1170470760052247,
#      'lng': 101.62209932197612,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 3.1170470760052247,
#        'lng': 101.62209932197612}],
#      'distance': 732,
#      'cc': 'MY',
#      'city': 'Ss2',
#      'state': 'Ss2',
#      'country': 'Malaysia',
#      'formattedAddress': ['Ss2 (Petaling Jaya)', 'Ss2, Ss2', 'Malaysia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606119521',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                       name  \
# 0  5822d3ff4c6d6738729f51a8  The Dessert Workshop 甜品工房
# 1  4d400a091bd2a143eaa3ee7c     Hong Kong Dessert 甜品哥哥
# 2  4f926ff0e4b0dcd91191bdce            Sisters Dessert
# 3  4ffd7cafe4b0cb44d977af12         Ice Palace Dessert
# 4  5a6043fc6adbf51970020930              Tim’s Dessert
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1606119521    False
# 1  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...  v-1606119521    False
# 2  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...  v-1606119521    False
# 3  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...  v-1606119521    False
# 4  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1606119521    False
#
#    location.lat  location.lng  \
# 0      3.119985    101.621514
# 1      3.118812    101.621947
# 2      3.114358    101.612289
# 3      3.114227    101.611564
# 4      3.113464    101.611000
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 3.119984764228635...                735
# 1  [{'label': 'display', 'lat': 3.118811901601927...                737
# 2  [{'label': 'display', 'lat': 3.114357709884643...                478
# 3  [{'label': 'display', 'lat': 3.11422694810422,...                550
# 4  [{'label': 'display', 'lat': 3.113464, 'lng': ...                652
#
#   location.cc  location.city location.state location.country  \
# 0          MY  Petaling Jaya       Selangor         Malaysia
# 1          MY  Petaling Jaya       Selangor         Malaysia
# 2          MY            NaN            NaN         Malaysia
# 3          MY            NaN            NaN         Malaysia
# 4          MY  Petaling Jaya       Selangor         Malaysia
#
#                      location.formattedAddress location.address  \
# 0          [Petaling Jaya, Selangor, Malaysia]              NaN
# 1  [Ss2/63, Petaling Jaya, Selangor, Malaysia]           Ss2/63
# 2                                   [Malaysia]              NaN
# 3                                   [Malaysia]              NaN
# 4    [47301 Petaling Jaya, Selangor, Malaysia]              NaN
#
#   location.postalCode location.crossStreet location.neighborhood
# 0                 NaN                  NaN                   NaN
# 1                 NaN                  NaN                   NaN
# 2                 NaN                  NaN                   NaN
# 3                 NaN                  NaN                   NaN
# 4               47301                  NaN                   NaN

# %%
dataframe.shape [0]
# Out:
# 11

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                          name    categories       lat         lng  \
# 0   The Dessert Workshop 甜品工房          Café  3.119985  101.621514
# 1      Hong Kong Dessert 甜品哥哥  Dessert Shop  3.118812  101.621947
# 2             Sisters Dessert  Dessert Shop  3.114358  101.612289
# 3          Ice Palace Dessert  Dessert Shop  3.114227  101.611564
# 4               Tim’s Dessert    Food Truck  3.113464  101.611000
# 5           Hong Kong Dessert  Dessert Shop  3.115519  101.621298
# 6           D&J Dessert Stall   Coffee Shop  3.120029  101.621507
# 7                 One Dessert  Dessert Shop  3.117034  101.622102
# 8                   U Dessert  Dessert Shop  3.118791  101.623191
# 9           K.T.Z. Food (记得食)  Dessert Shop  3.118428  101.622292
# 10            一品糖one desserts  Dessert Shop  3.117047  101.622099
#
#                                        labeledLatLngs  distance  cc  \
# 0   [{'label': 'display', 'lat': 3.119984764228635...       735  MY
# 1   [{'label': 'display', 'lat': 3.118811901601927...       737  MY
# 2   [{'label': 'display', 'lat': 3.114357709884643...       478  MY
# 3   [{'label': 'display', 'lat': 3.11422694810422,...       550  MY
# 4   [{'label': 'display', 'lat': 3.113464, 'lng': ...       652  MY
# 5   [{'label': 'display', 'lat': 3.115518555061557...       670  MY
# 6   [{'label': 'display', 'lat': 3.120028779896168...       736  MY
# 7   [{'label': 'display', 'lat': 3.117034408831739...       733  MY
# 8   [{'label': 'display', 'lat': 3.118791068891402...       871  MY
# 9   [{'label': 'display', 'lat': 3.118428093072506...       766  MY
# 10  [{'label': 'display', 'lat': 3.117047076005224...       732  MY
#
#              city     state   country  \
# 0   Petaling Jaya  Selangor  Malaysia
# 1   Petaling Jaya  Selangor  Malaysia
# 2             NaN       NaN  Malaysia
# 3             NaN       NaN  Malaysia
# 4   Petaling Jaya  Selangor  Malaysia
# 5   Petaling Jaya  Selangor  Malaysia
# 6             NaN       NaN  Malaysia
# 7   Petaling Jaya  Selangor  Malaysia
# 8             NaN       NaN  Malaysia
# 9   Petaling Jaya  Selangor  Malaysia
# 10            Ss2       Ss2  Malaysia
#
#                                      formattedAddress                 address  \
# 0                 [Petaling Jaya, Selangor, Malaysia]                     NaN
# 1         [Ss2/63, Petaling Jaya, Selangor, Malaysia]                  Ss2/63
# 2                                          [Malaysia]                     NaN
# 3                                          [Malaysia]                     NaN
# 4           [47301 Petaling Jaya, Selangor, Malaysia]                     NaN
# 5            [SS2, Petaling Jaya, Selangor, Malaysia]                     SS2
# 6   [Restoran Sun Hin Loong (SS2, Petaling Jaya), ...  Restoran Sun Hin Loong
# 7      [SS2, 47300 Petaling Jaya, Selangor, Malaysia]                     NaN
# 8                                          [Malaysia]                     NaN
# 9   [66 & 68, Jalan SS2/67, 47300 Petaling Jaya, S...   66 & 68, Jalan SS2/67
# 10          [Ss2 (Petaling Jaya), Ss2, Ss2, Malaysia]                     Ss2
#
#    postalCode         crossStreet neighborhood                        id
# 0         NaN                 NaN          NaN  5822d3ff4c6d6738729f51a8
# 1         NaN                 NaN          NaN  4d400a091bd2a143eaa3ee7c
# 2         NaN                 NaN          NaN  4f926ff0e4b0dcd91191bdce
# 3         NaN                 NaN          NaN  4ffd7cafe4b0cb44d977af12
# 4       47301                 NaN          NaN  5a6043fc6adbf51970020930
# 5         NaN                 NaN          NaN  4dce89e5e4cd130e1668caab
# 6         NaN  SS2, Petaling Jaya          NaN  4f6f41c7e4b0738fb3dedccf
# 7       47300                 SS2          NaN  4fe56f53e4b032d6530f4836
# 8         NaN                 NaN          NaN  544116c1498e51b65b4d3f5f
# 9       47300                 NaN          SS2  4b38d416f964a520da5025e3
# 10        NaN       Petaling Jaya          NaN  50068edae4b09db42e113b27

# %%
dataframe_filtered.name
# Out:
# 0     The Dessert Workshop 甜品工房
# 1        Hong Kong Dessert 甜品哥哥
# 2               Sisters Dessert
# 3            Ice Palace Dessert
# 4                 Tim’s Dessert
# 5             Hong Kong Dessert
# 6             D&J Dessert Stall
# 7                   One Dessert
# 8                     U Dessert
# 9             K.T.Z. Food (记得食)
# 10              一品糖one desserts
# Name: name, dtype: object

# %%
name = dataframe_filtered.name

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the Conrad Hotel

folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='SS2',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, name in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        color='blue',
        popup= name,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4f926ff0e4b0dcd91191bdce'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4f926ff0e4b0dcd91191bdce?client_id=W1MERJBEKLCR5DXSDELILM0VYAMJ2AFR42KHAWGQFCSXPQAT&client_secret=WME205ZHJ3HIP3JEQIYGAMB2AIQ5FMZS4NNNTLMXWYA0KSWH&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4f926ff0e4b0dcd91191bdce',
#  'name': 'Sisters Dessert',
#  'contact': {},
#  'location': {'lat': 3.1143577098846436,
#   'lng': 101.61228942871094,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 3.1143577098846436,
#     'lng': 101.61228942871094}],
#   'cc': 'MY',
#   'country': 'Malaysia',
#   'formattedAddress': ['Malaysia']},
#  'canonicalUrl': 'https://foursquare.com/v/sisters-dessert/4f926ff0e4b0dcd91191bdce',
#  'categories': [{'id': '4bf58dd8d48988d1d0941735',
#    'name': 'Dessert Shop',
#    'pluralName': 'Dessert Shops',
#    'shortName': 'Desserts',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0},
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'likes': {'count': 1,
#   'groups': [{'type': 'others',
#     'count': 1,
#     'items': [{'isSanctioned': False,
#       'firstName': 'Aiman',
#       'lastName': 'F',
#       'countryCode': 'MY'}]}],
#   'summary': '1 Like'},
#  'dislike': False,
#  'ok': False,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 0, 'groups': []},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1334996976,
#  'tips': {'count': 0, 'groups': []},
#  'shortUrl': 'http://4sq.com/JVQjXP',
#  'timeZone': 'Asia/Kuala_Lumpur',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dessert',
#     'count': 8,
#     'items': [{'displayName': 'Dessert', 'displayValue': 'Dessert'}]}]}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4ffd7cafe4b0cb44d977af12'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4ffd7cafe4b0cb44d977af12?client_id=W1MERJBEKLCR5DXSDELILM0VYAMJ2AFR42KHAWGQFCSXPQAT&client_secret=WME205ZHJ3HIP3JEQIYGAMB2AIQ5FMZS4NNNTLMXWYA0KSWH&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4ffd7cafe4b0cb44d977af12',
#  'name': 'Ice Palace Dessert',
#  'contact': {},
#  'location': {'lat': 3.11422694810422,
#   'lng': 101.61156397514624,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 3.11422694810422,
#     'lng': 101.61156397514624}],
#   'cc': 'MY',
#   'country': 'Malaysia',
#   'formattedAddress': ['Malaysia']},
#  'canonicalUrl': 'https://foursquare.com/v/ice-palace-dessert/4ffd7cafe4b0cb44d977af12',
#  'categories': [{'id': '4bf58dd8d48988d1d0941735',
#    'name': 'Dessert Shop',
#    'pluralName': 'Dessert Shops',
#    'shortName': 'Desserts',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0},
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'likes': {'count': 0, 'groups': []},
#  'dislike': False,
#  'ok': False,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 0, 'groups': []},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1342012591,
#  'tips': {'count': 0, 'groups': []},
#  'shortUrl': 'http://4sq.com/NgyE0j',
#  'timeZone': 'Asia/Kuala_Lumpur',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price',
#       'displayValue': '$',
#       'priceTier': 1}]}]}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '5a6043fc6adbf51970020930'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/5a6043fc6adbf51970020930?client_id=W1MERJBEKLCR5DXSDELILM0VYAMJ2AFR42KHAWGQFCSXPQAT&client_secret=WME205ZHJ3HIP3JEQIYGAMB2AIQ5FMZS4NNNTLMXWYA0KSWH&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '5a6043fc6adbf51970020930',
#  'name': 'Tim’s Dessert',
#  'contact': {},
#  'location': {'lat': 3.113464,
#   'lng': 101.611,
#   'labeledLatLngs': [{'label': 'display', 'lat': 3.113464, 'lng': 101.611}],
#   'postalCode': '47301',
#   'cc': 'MY',
#   'city': 'Petaling Jaya',
#   'state': 'Selangor',
#   'country': 'Malaysia',
#   'formattedAddress': ['47301 Petaling Jaya, Selangor', 'Malaysia']},
#  'canonicalUrl': 'https://foursquare.com/v/tims-dessert/5a6043fc6adbf51970020930',
#  'categories': [{'id': '4bf58dd8d48988d1cb941735',
#    'name': 'Food Truck',
#    'pluralName': 'Food Trucks',
#    'shortName': 'Food Truck',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0},
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'likes': {'count': 0, 'groups': []},
#  'dislike': False,
#  'ok': False,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 0, 'groups': []},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1516258300,
#  'tips': {'count': 0, 'groups': []},
#  'shortUrl': 'http://4sq.com/2EPxiuD',
#  'timeZone': 'Asia/Kuala_Lumpur',
#  'listed': {'count': 0,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 0,
#     'items': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price',
#       'displayValue': '$',
#       'priceTier': 1}]}]}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fbbaccb3023093e6235488b'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'
